# %% [markdown]
# # Football Manager Analysis
#
# ## Set-up Environment

# %%
# Import libraries
import os
import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport
import html5lib

# %%
# Set number of columns to display in dataframe to 60
pd.set_option('display.max_columns', 60)

# %% [markdown]
# ### Set-up Folders

# %%
path = '/Users/nicksolly/Dev/footballManager/'
# Get the current working directory
cwd = os.getcwd()

print(f'Current working directory: {cwd}')
# Out:
# Current working directory: /Users/nicksolly/Dev/footballManager/notebooks

# %% [markdown]
# ## Import exported file from FM24 in html format

# %%
# Define the file name
file_name = '20231109-Squad-NCL-AllAtributes.html'

# Define the file path
file_path = os.path.join(cwd, 'data', 'raw', file_name)

print(f'File path: {file_path}')
# Out:
# File path: /Users/nicksolly/Dev/footballManager/notebooks/data/raw/20231109-Squad-NCL-AllAtributes.html

# %%
# Import HTML file into pandas DataFrame 
df_squad = pd.read_html(file_path)

# print df_squad
print(df_squad)

# df_squad.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/nicksolly/Dev/footballManager/notebooks/team_analysis.ipynb Cell 8 line 2
#       <a href='vscode-notebook-cell:/Users/nicksolly/Dev/footballManager/notebooks/team_analysis.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> # Import HTML file into pandas DataFrame
# ----> <a href='vscode-notebook-cell:/Users/nicksolly/Dev/footballManager/notebooks/team_analysis.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> df_squad = pd.read_html(file_path)
#       <a href='vscode-notebook-cell:/Users/nicksolly/Dev/footballManager/notebooks/team_analysis.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> # print df_squad
#       <a href='vscode-notebook-cell:/Users/nicksolly/Dev/footballManager/notebooks/team_analysis.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> print(df_squad)
#
# ...

# %%
df_squad.columns.nunique()
# Out:
# 57

# %%
df_squad.describe()
# Out:
#              Age        1v1        Acc        Aer        Agg        Agi  \
# count  83.000000  83.000000  83.000000  83.000000  83.000000  83.000000
# mean   21.795181   3.180723  12.433735   3.506024  10.722892  11.638554
# std     5.195587   3.335488   2.922548   3.576255   3.224575   2.611318
# min    15.000000   1.000000   3.000000   1.000000   5.000000   5.000000
# 25%    18.000000   2.000000  11.000000   2.000000   8.000000  10.000000
# 50%    20.000000   2.000000  13.000000   3.000000  11.000000  12.000000
# 75%    25.000000   3.000000  14.000000   3.000000  13.000000  13.000000
# max    34.000000  18.000000  19.000000  18.000000  17.000000  17.000000
#
#              Ant        Bal        Bra        Cmd        Cnt        Cmp  \
# count  83.000000  83.000000  83.000000  83.000000  83.000000  83.000000
# mean    9.939759   9.891566  10.698795   3.216867   9.277108   9.566265
# std     3.951997   3.467663   3.760303   3.174011   3.493245   3.765028
# ...

# %%
df_squad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 57 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Reg             83 non-null     object
#  1   Inf             83 non-null     object
#  2   Name            83 non-null     object
#  3   Age             83 non-null     int64
#  4   Wage            83 non-null     object
#  5   Transfer Value  83 non-null     object
#  6   Nat             83 non-null     object
#  7   2nd Nat         83 non-null     object
#  8   Position        83 non-null     object
#  9   Personality     83 non-null     object
#  10  Media Handling  83 non-null     object
#  11  Av Rat          83 non-null     object
#  12  Left Foot       83 non-null     object
#  13  Right Foot      83 non-null     object
#  14  Height          83 non-null     object
#  15  1v1             83 non-null     int64
#  16  Acc             83 non-null     int64
# ...
